# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
x=6*np.random.rand(100,1)-3
y=0.5*x**2+1.5*x+2+np.random.randn(100,1)

# %%
plt.scatter(x,y,color='green')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#simple linear regression
from sklearn.linear_model import LinearRegression

lin_reg=LinearRegression()

lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
score= r2_score(y_test,lin_reg.predict(x_test))
print(score)
# Out:
# 0.7448230831611257

# %%
#VISUALIZE THIS MODEL
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,lin_reg.predict(x_train),color='red')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
#aplly polynomial transformation
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=2,include_bias=True)
x_train_poly=poly_reg.fit_transform(x_train) 
x_test_poly=poly_reg.transform(x_test)

# %%
from sklearn.metrics import r2_score
regression=LinearRegression()
regression.fit(x_train_poly,y_train)
y_pred=regression.predict(x_test_poly)

score= r2_score(y_test,y_pred)
print(score)
# Out:
# 0.9531254479089339

# %%
print(regression.coef_)
# Out:
# [[0.         1.51221287 0.46850102]]

# %%
print(regression.intercept_)
# Out:
# [1.90083468]

# %%
plt.scatter(x_train,regression.predict(x_train_poly),color='red')
plt.scatter(x_train,y_train)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=3,include_bias=True)
x_train_poly=poly_reg.fit_transform(x_train) 
x_test_poly=poly_reg.transform(x_test)

# %%
x_train_poly
# Out:
# array([[ 1.00000000e+00,  1.72371595e+00,  2.97119667e+00,
#          5.12149908e+00],
#        [ 1.00000000e+00,  2.41738613e+00,  5.84375569e+00,
#          1.41266139e+01],
#        [ 1.00000000e+00, -4.03480864e-03,  1.62796808e-05,
#         -6.56853968e-08],
#        [ 1.00000000e+00, -2.20010275e+00,  4.84045210e+00,
#         -1.06494920e+01],
#        [ 1.00000000e+00,  2.15274883e-01,  4.63432753e-02,
#          9.97654317e-03],
#        [ 1.00000000e+00, -7.40412597e-01,  5.48210814e-01,
#         -4.05902193e-01],
#        [ 1.00000000e+00,  2.71433335e+00,  7.36760555e+00,
#          1.99981375e+01],
#        [ 1.00000000e+00,  2.87116377e+00,  8.24358140e+00,
#          2.36686722e+01],
#        [ 1.00000000e+00,  3.59284813e-01,  1.29085577e-01,
#          4.63784874e-02],
#        [ 1.00000000e+00,  2.56760437e+00,  6.59259220e+00,
#          1.69271686e+01],
#        [ 1.00000000e+00, -7.57780100e-01,  5.74230680e-01,
#         -4.35140582e-01],
#        [ 1.00000000e+00, -2.04380921e+00,  4.17715607e+00,
#         -8.53731003e+00],
#        [ 1.00000000e+00, -2.72702750e+00,  7.43667901e+00,
#         -2.02800282e+01],
#        [ 1.00000000e+00, -2.90228086e+00,  8.42323417e+00,
#         -2.44465913e+01],
#        [ 1.00000000e+00, -2.39987457e+00,  5.75939796e+00,
#         -1.38218327e+01],
#        [ 1.00000000e+00, -1.92195734e+00,  3.69392002e+00,
#         -7.09955670e+00],
#        [ 1.00000000e+00,  1.38343218e+00,  1.91388459e+00,
#          2.64772952e+00],
#        [ 1.00000000e+00, -2.00489785e+00,  4.01961538e+00,
#         -8.05891823e+00],
#        [ 1.00000000e+00, -1.85651222e+00,  3.44663764e+00,
#         -6.39872490e+00],
#        [ 1.00000000e+00, -6.23206429e-01,  3.88386253e-01,
#         -2.42044810e-01],
#        [ 1.00000000e+00,  2.35222287e+00,  5.53295243e+00,
#          1.84095699e+01],
#        [ 1.00000000e+00, -1.83194105e+00,  3.35600800e+00,
#         -6.14800881e+00],
#        [ 1.00000000e+00, -2.28401432e+00,  5.21672141e+00,
#         -1.19150664e+01],
#        [ 1.00000000e+00,  5.43524639e-02,  2.95419033e-03,
#          1.60567524e-04],
#        [ 1.00000000e+00,  9.88669874e-01,  9.77468120e-01,
#          9.66393283e-01],
#        [ 1.00000000e+00,  1.38566135e+00,  1.92005738e+00,
#          2.66054930e+00],
#        [ 1.00000000e+00,  1.88754257e+00,  3.56281695e+00,
#          6.72496866e+00],
#        [ 1.00000000e+00, -4.92940654e-01,  2.42990489e-01,
#         -1.19779890e-01],
#        [ 1.00000000e+00, -8.05907495e-02,  6.49486890e-03,
#         -5.23426353e-04],
#        [ 1.00000000e+00,  4.86351171e-01,  2.36537462e-01,
#          1.15040272e-01],
#        [ 1.00000000e+00, -1.96638397e+00,  3.86666591e+00,
#         -7.60334987e+00],
#        [ 1.00000000e+00,  1.88861106e+00,  3.56685175e+00,
#          6.73639569e+00],
#        [ 1.00000000e+00, -1.74375562e+00,  3.04068367e+00,
#         -5.30220925e+00],
#        [ 1.00000000e+00,  2.40701088e+00,  5.79370140e+00,
#          1.39455023e+01],
#        [ 1.00000000e+00, -2.48611466e+00,  6.18076612e+00,
#         -1.53660933e+01],
#        [ 1.00000000e+00,  2.81536856e+00,  7.92630012e+00,
#          2.23154562e+01],
#        [ 1.00000000e+00,  2.31319482e+00,  5.35087027e+00,
#          1.23776054e+01],
#        [ 1.00000000e+00,  1.79270522e-01,  3.21379200e-02,
#          5.76138169e-03],
#        [ 1.00000000e+00,  2.38457159e+00,  5.68618166e+00,
#          1.35591072e+01],
#        [ 1.00000000e+00, -2.52876522e+00,  6.39465354e+00,
#         -1.61705775e+01],
#        [ 1.00000000e+00, -8.27345958e-01,  6.84501335e-01,
#         -5.66319413e-01],
#        [ 1.00000000e+00, -2.01561528e+00,  4.06270495e+00,
#         -8.18885018e+00],
#        [ 1.00000000e+00, -2.28811513e+00,  5.23547086e+00,
#         -1.19793601e+01],
#        [ 1.00000000e+00,  1.23648581e+00,  1.52889716e+00,
#          1.89045965e+00],
#        [ 1.00000000e+00, -4.83702041e-01,  2.33967664e-01,
#         -1.13170637e-01],
#        [ 1.00000000e+00, -1.02806660e+00,  1.05692093e+00,
#         -1.08658510e+00],
#        [ 1.00000000e+00, -2.28266996e+00,  5.21058214e+00,
#         -1.18940393e+01],
#        [ 1.00000000e+00, -1.19844811e+00,  1.43627787e+00,
#         -1.72130451e+00]])

# %%
#predict on test data
x_new= np.linspace(-3, 3, 200).reshape(200, 1)
x_new_poly = poly_reg.transform(x_new)

# %%
y_new=regression.predict(x_new_poly)

plt.plot(x_new, y_new, "r-", linewidth=2, label="New Predictions")
plt.plot(x_train, y_train, "b.",label="Training points")
plt.plot(x_test, y_test, "g.",label="Testing points")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(loc="upper left", fontsize=10)
plt.show()
