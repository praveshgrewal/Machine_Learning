# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("student_clustering.csv")
df.shape
# Out:
# (200, 2)

# %%
df
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'])

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]

for i in range(1,11):
    km = KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)

# %%
wcss
# Out:
# [29957.898287999997,
#  4184.14127,
#  2362.7133490000006,
#  681.96966,
#  599.4812142280703,
#  405.12058406910546,
#  336.50554710765425,
#  394.6105789680558,
#  271.36586669788585,
#  182.33090074229693]

# %%
plt.plot(range(1,11))

# %%
x= df.iloc[:,:].values

km = KMeans(n_clusters=4)
y_mean= km.fit_predict(x)

# %%
y_mean
# Out:
# array([2, 3, 0, 0, 3, 3, 0, 1, 3, 0, 2, 3, 0, 2, 3, 0, 3, 0, 3, 3, 0, 2,
#        0, 2, 2, 0, 2, 1, 0, 3, 1, 3, 1, 3, 0, 0, 1, 3, 2, 3, 2, 0, 0, 2,
#        1, 1, 0, 3, 1, 3, 2, 2, 1, 0, 1, 3, 3, 1, 3, 1, 3, 0, 0, 1, 2, 1,
#        0, 2, 3, 0, 3, 1, 0, 2, 3, 1, 3, 1, 2, 0, 0, 1, 3, 2, 1, 2, 1, 3,
#        1, 3, 1, 1, 0, 2, 0, 0, 1, 0, 2, 1, 3, 2, 2, 1, 2, 2, 0, 2, 1, 1,
#        0, 1, 3, 3, 0, 1, 0, 3, 1, 2, 2, 3, 0, 1, 0, 2, 0, 3, 2, 0, 0, 3,
#        2, 2, 3, 1, 3, 2, 0, 0, 0, 2, 3, 2, 2, 1, 2, 1, 3, 2, 1, 2, 1, 1,
#        2, 0, 3, 1, 3, 0, 2, 1, 3, 0, 1, 2, 3, 2, 2, 1, 1, 3, 1, 2, 2, 0,
#        1, 3, 2, 1, 1, 3, 3, 3, 0, 2, 0, 0, 1, 3, 0, 0, 2, 2, 0, 2, 1, 3,
#        3, 1])

# %%
x[y_mean == 2,1]
# Out:
# array([88., 86., 88., 86., 87., 88., 87., 84., 85., 86., 83., 86., 87.,
#        85., 83., 88., 85., 88., 86., 91., 86., 88., 89., 86., 90., 87.,
#        87., 85., 87., 83., 86., 87., 85., 87., 87., 88., 88., 85., 86.,
#        86., 86., 85., 88., 88., 89., 88., 88., 89., 85., 89.])

# %%
plt.scatter(x[y_mean == 0,0],x[y_mean == 0,1],color = 'blue')
plt.scatter(x[y_mean == 1,0],x[y_mean == 1,1],color = 'red')
plt.scatter(x[y_mean == 2,0],x[y_mean == 2,1],color = 'yellow')
plt.scatter(x[y_mean == 3,0],x[y_mean == 3,1],color = 'green')

# %% [markdown]
# # 3D

# %%
from sklearn.datasets import make_blobs

# %%
cent = [(-5,-5,5),(5,5,-5),(3.5,-2.5,4),(-2.5,2.5,-4)]
clu= [1,1,1,1]

# %%
x,y= make_blobs(n_samples=200,cluster_std = clu, centers=cent,n_features=3,random_state=42)

# %%
x
# Out:
# array([[-5.54438272, -4.88907741,  3.84900642],
#        [-6.05771093, -4.17745509,  3.77915635],
#        [-6.40185106, -4.41314291,  7.19045563],
#        [-5.19236096, -4.69845266,  4.96528823],
#        [-5.56228753, -6.01283112,  5.31424733],
#        [ 5.1990597 ,  4.39978312, -4.93019792],
#        [-3.69787789,  4.46472513, -3.96473645],
#        [ 5.86575519,  3.79970359, -5.33450124],
#        [-5.50347565, -6.55066343,  5.06856297],
#        [ 2.74086734, -2.34960621,  4.34175598],
#        [-0.4245992 ,  3.3711247 , -4.32602353],
#        [-2.60703036,  1.46475768, -4.55364931],
#        [-1.96108996,  1.46275385, -4.19033868],
#        [-2.18874985,  5.57888081, -2.88042509],
#        [-5.11564828, -5.3011037 ,  3.52147801],
#        [ 4.97535622, -1.64234038,  3.84006147],
#        [-3.47697014, -5.23415337,  4.76586304],
#        [-3.14657288,  1.418452  , -2.31285836],
#        [ 2.49398262, -3.71418861,  5.15811087],
#        [ 3.73204994, -3.94808434,  2.59253623],
# ...

# %%
import plotly.express as px
fig = px.scatter_3d(x= x[:,0],y= x[:,1],z=x[:,2])
fig.show()

# %%
wcss=[]

for i in range(1,11):
    km = KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)

# %%
plt.plot (range(1,11),wcss)

# %%
km = KMeans(n_clusters=4)
y_pred = km.fit_predict(x)

# %%
df = pd.DataFrame()

df['col1'] = x[:,0]
df['col2'] = x[:,1]
df['col3'] = x[:,2]
df['label'] = y_pred

# %%
fig = px.scatter_3d(df,x='col1',y= 'col2',z='col3',color='label')
fig.show()
